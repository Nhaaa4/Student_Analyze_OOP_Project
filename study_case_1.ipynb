# %%
from src.data_loader import DataLoader
from src.analyze_dataset import AllStudentPerformanceAnalyze

def all_students_analyze(data, all_std_ana):

    print(data.data_sample())
    print(data.data_info())
    print(data.data_describe())

    all_std_ana.final_grade_analyze()
    all_std_ana.study_hour_analyze()
    all_std_ana.learning_style_analyze()
    all_std_ana.discussion_analyze()
    all_std_ana.assignment_rate_analyze()
    all_std_ana.exam_score_analyze()
    all_std_ana.attendance_rate_analyze()
    all_std_ana.stress_report_analyze()
    all_std_ana.free_time_analyze()
    all_std_ana.sleep_hours_analyze()

file_path = 'data/student_clean.csv'

data = DataLoader(file_path)
df = data.get_data()

all_std_ana = AllStudentPerformanceAnalyze(df)

all_students_analyze(data, all_std_ana)
# Out:
#      Study/Week   Learning_Style  Online_Courses_Completed  \
# 138          42      Kinesthetic                         5
# 131          32      Kinesthetic                         2
# 285          29  Reading/Writing                        14
# 19           28         Auditory                        19
# 386          22           Visual                        17
# 319          16  Reading/Writing                        17
# 228          37      Kinesthetic                         4
# 57           19  Reading/Writing                         5
# 378          43  Reading/Writing                        14
# 422          47  Reading/Writing                         5
#
#     Participation_in_Discussions  Assignment_Completion_Rate  Exam_Score  \
# 138                           No                          53          84
# 131                           No                          66          79
# 285                           No                         100          54
# 19                            No                          50          64
# 386                          Yes                          50          45
# 319                          Yes                          84          63
# 228                          Yes                          73          45
# 57                            No                          53          85
# 378                          Yes                          56          88
# 422                          Yes                          52          85
#
#      Attendance_Rate Stress_Level  Free_Time_/Week  Sleep/Night Final_Grade
# 138               93          Low               16            4           B
# 131               61       Medium               20            8           B
# 285               64       Medium               17            7           D
# 19                80       Medium               20            8           C
# 386               88       Medium                5            5           D
# 319               91       Medium                0            8           C
# 228               60          Low               16            7           D
# 57                71       Medium               29            9           A
# 378               77       Medium                2            4           A
# 422               83         High                7            8           A
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Study/Week                    500 non-null    int64
#  1   Learning_Style                500 non-null    object
#  2   Online_Courses_Completed      500 non-null    int64
#  3   Participation_in_Discussions  500 non-null    object
#  4   Assignment_Completion_Rate    500 non-null    int64
#  5   Exam_Score                    500 non-null    int64
#  6   Attendance_Rate               500 non-null    int64
#  7   Stress_Level                  500 non-null    object
#  8   Free_Time_/Week               500 non-null    int64
#  9   Sleep/Night                   500 non-null    int64
#  10  Final_Grade                   500 non-null    object
# dtypes: int64(7), object(4)
# memory usage: 43.1+ KB
# None
#        Study/Week  Online_Courses_Completed  Assignment_Completion_Rate  \
# count  500.000000                500.000000                  500.000000
# mean    27.058000                  9.948000                   73.956000
# std     13.074422                  6.132905                   15.102259
# min      5.000000                  0.000000                   50.000000
# 25%     15.000000                  5.000000                   61.000000
# 50%     27.000000                 10.000000                   73.000000
# 75%     39.000000                 15.000000                   88.000000
# max     49.000000                 20.000000                  100.000000
#
#        Exam_Score  Attendance_Rate  Free_Time_/Week  Sleep/Night
# count  500.000000       500.000000       500.000000   500.000000
# mean    68.390000        74.848000        14.142000     7.014000
# std     17.088884        14.821344         9.020897     1.973218
# min     40.000000        50.000000         0.000000     4.000000
# 25%     54.000000        62.000000         6.000000     5.000000
# 50%     69.000000        75.000000        14.000000     7.000000
# 75%     83.000000        87.000000        21.000000     9.000000
# max    100.000000       100.000000        30.000000    10.000000
# 1. Graph below show the number of student by final grade
# In this picture, there are bars chart that present the relationship between Number of Student
# and Final Grade. There are four categories of the student grade (A, B, C, D) and the limit of the
# number of student in each category is 140. The First pie chart present 108 student that has grade A,
# and it is the least amount of student among the grade, follow by Grade B that has 132 and Grade C
# that has 125 student, and Grade D has 135 student which is the most common grade in the chart.
#
# 2. Graph below show the study hours per week compare their grade
# This is a line graph that present about the relationship between Average Study Hours per week with
# Final Grade. For Grade A students spent less than 27 hours per week, followed by grade B student study
# less than 26.5 hour per week, for grade C student spent less than 27.5 hours per week, while student with
# Grade D student spent 28 hours per week. This graph show that student in Grade A spent their time efficient
# than grade D which study more than 28 hours and did not get good result.
#
# 3. Graph below show the preffferred learning style compare their grade
# Describe: This is 4 pie charts which represent the relationship between learning style and final grade
# (A, B, C and D). Each chart categorize student into four learning style such as Visual, Kinesthetic,
# Auditory and Reading/Writing. Grade A student mostly prefered Visual learning (31.5%), followed Kinesthetic
# (26.9%) and Reading/Writing learning (23.1%), and Auditory learning (18.5%) is the least common learning
# style that student prefered. The second pie chart present the relationship between learning and final grade B.
# Student grade B mostly prefered Auditory learnining (27.3%) which is the common learning style that the student
# prefered in grade B, followed by Reading/Writing learning (26.5%) and Visual learning (25.8%), and Kinesthetic
# (20.5%) the least common learning style in grade B represented chart. Grade C chart, Most student prefered Auditory
# learning (26.4%), followed by Visual learning (25.6%) and Kinesthetic learning (23.2%), and Reading/Writing (23.25)
# is the least common learning style prefered. Grade D, Reading/Writing (27.4%) is the most common learning, followed
# by Kinesthetic learning (25.9%) and Visual learning (25.2%), and Auditory learning (21.5%) the least common learning
# style in grade D. This chart suggest the student to prefered Visual learning becuase it is poppular in grade A.
# Student grade D mostly prefer Reading/Writing learning.
#
# 4. Graph below show the participation in discussion compare their grade
# This is a box chart that present the relationship between Discussion and Final Grade. These chart mean that
# discussion does not affect on student grade since these chart are perfectly the same.
#
# 5. Graph below show the assignment rate with their grade
# This graph present about Average Assignment Completion Rate by Final grade The limit average assignment completion rate is 75%
# and the Final Grad is A, B, C, and D. Student grade A has the highest assignment completion rate (more than 75%), student grade B
# has the lowest assignment completion rate (less than 72.5%), student grade C (less than 74%), student with grade D has 74.5%
# completion rate. This mean that the data is not have no affect on the grade.
#
# 6. Graph below show the exam score with their grade
# This is a box chart that present the Exam Score Distribution by Final Grade. The limit score is 100 percentage and Final Grade
# (A, B, C, D). Student Grade C has more than 60%, Student Grade D has less than 50%, Student Grade B has more than 70% but less
# than 80%, Student Grade A has more than 93%.
#
# 7. Graph below show the attendace rate with their grade
# This histogram show about the Comparison of Attendance Rate with Grade (A, B, C, D), Student Grade A attend the class less
# than the other grade, Student Grade B attend class more than others, followed by Grade C and Grade D which attend the class
# more than grade A. This histogram of Attendance Rate does not affect on the student grade.
#
# 8. Graph below show the self reported stress level with their grade
# This bar chart present the relationship between the number of student with final grade of student that have the level of stress.
# There are 3 level of stress such as High (Blue), Medium (Medium), Low (Low), Grade A student with the high stress(22), medium(54),
# low(32), Student grade B, high level of stress (24), medium (73), low (35). Student Grade C, High(27), Medium (64), Low (34).
# Student with grade D, High (24), Medium (57), Low (54).This chart show that student with grade A has the least stress level High,
# Medium, Low compare to other Grade.
#
# 9. Graph below show the free time with their grade
# This is a histogram that explain about the Comparison of Free Time (hours/week) by Grade. The limit of free time hour is
# from - 10 to 40 hours a week. The highest free time level of stress is  Grade B free time between 10 to 30  and Grade C
# free time between 0 to 10 students, follow by Grade D student who has free time between 10 to 20 hours, Student Grade A has
# the least free time between 0 to 10 hours. This histogram show us about the performance of each grade of student, Student
# grade A has the least free time than grade B, C, and D.
#
# 10. Graph below show the sleep hours per night with their grade
# This histogram explain about the comparison of sleep hour per night by grade. the limit of sleep hour is from 2 to 12 hour.
# Student grade sleep 8 hours a day. while grade B sleep between 6 to 8 hours. Grade C student sleep between 4 to 8 hours .
# Student Grade D sleep between 4 to more than 10 hours.
